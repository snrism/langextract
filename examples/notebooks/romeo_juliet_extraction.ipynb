# %% [markdown]
# # Romeo and Juliet Text Extraction with LangExtract
#
# This notebook demonstrates extracting characters, emotions, and relationships from Shakespeare's Romeo and Juliet using LangExtract.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/google/langextract/blob/main/examples/notebooks/romeo_juliet_extraction.ipynb)

# %% [markdown]
# ## Setup

# %%
# Install LangExtract
# %pip install -q langextract
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.8 MB/s eta 0:00:00

# %%
# Set up your Gemini API key
# Get your key from: https://aistudio.google.com/app/apikey
import os
from getpass import getpass

if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = getpass('Enter your Gemini API key: ')
# Out:
# AIzaSyA1oNZnhvoIpeIdUZu_MsCmAjbCcX0oCFQ··········

# %% [markdown]
# ## Define Extraction Task

# %%
import langextract as lx
import textwrap

prompt = textwrap.dedent("""\
    Extract key entities and attributes from an identification document.
    Use exact text where possible. Do not paraphrase names or IDs.
    Include: person, document, id_number, address, dates (dob, issue, expiry),
    classifications (class, endorsements, restrictions), and flags (organ_donor).
""")

examples = [
    lx.data.ExampleData(
        text=fake_license,
        extractions=[
            lx.data.Extraction(
                extraction_class="document",
                extraction_text="DRIVER LICENSE",
                attributes={"jurisdiction": "STATE OF PACIFICA"}
            ),
            lx.data.Extraction(
                extraction_class="id_number",
                extraction_text="P123-456-789",
                attributes={"label": "DLN"}
            ),
            lx.data.Extraction(
                extraction_class="person",
                extraction_text="RIVERA, ALEX J",
                attributes={"given_name": "ALEX", "family_name": "RIVERA", "middle_initial": "J"}
            ),
            lx.data.Extraction(
                extraction_class="address",
                extraction_text="1420 Beacon Ave, Apt 5B, Northport, PC 94021",
                attributes={"city": "Northport", "postal_code": "94021", "region": "PC"}
            ),
            lx.data.Extraction(
                extraction_class="date",
                extraction_text="1991-07-18",
                attributes={"type": "DOB"}
            ),
            lx.data.Extraction(
                extraction_class="date",
                extraction_text="2024-06-15",
                attributes={"type": "Issue"}
            ),
            lx.data.Extraction(
                extraction_class="date",
                extraction_text="2032-07-18",
                attributes={"type": "Exp"}
            ),
            lx.data.Extraction(
                extraction_class="classification",
                extraction_text="Class: C",
                attributes={"class": "C"}
            ),
            lx.data.Extraction(
                extraction_class="endorsement",
                extraction_text="Endorsements: None",
                attributes={"endorsements": "None"}
            ),
            lx.data.Extraction(
                extraction_class="restriction",
                extraction_text="Restr: Corrective Lenses",
                attributes={"restriction": "Corrective Lenses"}
            ),
            lx.data.Extraction(
                extraction_class="flag",
                extraction_text="Organ Donor: YES",
                attributes={"organ_donor": "YES"}
            ),
            lx.data.Extraction(
                extraction_class="note",
                extraction_text="Temporary address valid until 2025-01-31.",
                attributes={"type": "address_validity"}
            ),
        ]
    )
]

# %% [markdown]
# ## Extract from Sample Text

# %%
# Simple extraction from a short text
fake_license = textwrap.dedent("""\
    STATE OF PACIFICA • DRIVER LICENSE
    DLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses
    Name: RIVERA, ALEX J
    Address: 1420 Beacon Ave, Apt 5B, Northport, PC 94021
    DOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18
""")

noisy_license = textwrap.dedent("""\
    ====== Document Scan (IMG_2031.JPG) ======
    STATE OF PACIFICA • DRIVER LICENSE
    [Help? Call 1-800-PACIFICA • v3.9.2 • Print: 2024-06-16T08:12Z]

    ▶ CUSTOMER COPY – NOT VALID FOR TRAVEL
    DLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses
    Name: RIVERA, ALEX J
    Address: 1420 Beacon Ave, Apt 5B, Northport, PC 94021
    DOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18

    ---- FOOTNOTES / SYSTEM LOGS -------------------------------------
    • Reprint reason: Card damaged (case #NP-88412).
    • Payment Ref: 77-22-991  Auth: OK
    • Barcode (Code128): |||:::|||:::
    • “Birth Date” (legacy field): 1991/07/18
    • Issued by: DMV Northport Office (Window 3)
    • Temp Visitor Until: 2026-01-01 (does not change card expiration)
    • Prior Customer ID: P123-456-780 (deprecated)
    • D1N (OCR guess): P123-456-789  <-- ignore OCR guess key

    ---- RANDOM INSERTS / AD SPACE -----------------------------------
    Get 15% off car registration with SAFE-DRIVE course!  Promo ends 07/31.
    Terms apply. See pacifica.gov/safe-drive.  © State of Pacifica.

    ---- DUPLICATED METADATA (SHADOW SCAN) ---------------------------
    STATE OF PACIFICA — DRIVER LICENSE — SAMPLE
    Name: Rivera, Alex J.    Class C     (this line may vary casing/punctuation)
    Exp: 2032-07-18  Issue: 2024-06-15  DOB: 1991-07-18
    Address on file: 1420 Beacon Ave Apt 5B Northport PC 94021

    ---- PAGE 2 (BACK SIDE OCR MERGE) --------------------------------
    EMERGENCY CONTACT (self-reported): Aunt M. Rivera  (555) 212-9090
    Organ Donor: YES   Veteran: NO
    Restrictions: Corrective Lenses
    Endorsements: None
    Signature: /ARivera/
    ------------------------------------------------------------------
    End of Scan
"""

result = lx.extract(
    text_or_documents=noisy_license,
    prompt_description=prompt,
    examples=examples,
    model_id="gemini-2.5-flash",
)

# Display results
print(f"Extracted {len(result.extractions)} entities:\n")
for extraction in result.extractions:
    print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
    if extraction.attributes:
        for key, value in extraction.attributes.items():
            print(f"  - {key}: {value}")
# Out:
# 2025-08-17 18:42:34,190 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.__init__(self=<GeminiLanguageModel>, constraint=Constraint(co...NONE: 'none'>), kwargs={})
# 2025-08-17 18:42:34,191 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.__init__ -> None (0.0 ms)
# 2025-08-17 18:42:34,193 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.apply_schema(self=<GeminiLanguageModel>, schema_instance=GeminiSchema(...xtractions']}))
# 2025-08-17 18:42:34,193 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.apply_schema -> None (0.0 ms)
# DEBUG:absl:Initialized Annotator with prompt:
# Extract key entities and attributes from an identification document.
# Use exact text where possible. Do not paraphrase names or IDs.
# Include: person, document, id_number, address, dates (dob, issue, expiry),
# classifications (class, endorsements, restrictions), and flags (organ_donor).
#
#
# Examples
# Q: STATE OF PACIFICA • DRIVER LICENSE
# DLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses
# Name: RIVERA, ALEX J
# Address: 1420 Beacon Ave, Apt 5B, Northport, PC 94021
# DOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18
# Sex: M   Hgt: 5'11"   Wgt: 178 lb   Eyes: BRN
# Organ Donor: YES
# Notes: Temporary address valid until 2025-01-31.
# Barcode: |||:::|||:::
#
# A: {
#   "extractions": [
#     {
#       "document": "DRIVER LICENSE",
#       "document_attributes": {
#         "jurisdiction": "STATE OF PACIFICA"
#       }
#     },
#     {
#       "id_number": "P123-456-789",
#       "id_number_attributes": {
#         "label": "DLN"
#       }
#     },
#     {
#       "person": "RIVERA, ALEX J",
#       "person_attributes": {
#         "given_name": "ALEX",
#         "family_name": "RIVERA",
#         "middle_initial": "J"
#       }
#     },
#     {
#       "address": "1420 Beacon Ave, Apt 5B, Northport, PC 94021",
#       "address_attributes": {
#         "city": "Northport",
#         "postal_code": "94021",
#         "region": "PC"
#       }
#     },
#     {
#       "date": "1991-07-18",
#       "date_attributes": {
#         "type": "DOB"
#       }
#     },
#     {
#       "date": "2024-06-15",
#       "date_attributes": {
#         "type": "Issue"
#       }
#     },
#     {
#       "date": "2032-07-18",
#       "date_attributes": {
#         "type": "Exp"
#       }
#     },
#     {
#       "classification": "Class: C",
#       "classification_attributes": {
#         "class": "C"
#       }
#     },
#     {
#       "endorsement": "Endorsements: None",
#       "endorsement_attributes": {
#         "endorsements": "None"
#       }
#     },
#     {
#       "restriction": "Restr: Corrective Lenses",
#       "restriction_attributes": {
#         "restriction": "Corrective Lenses"
#       }
#     },
#     {
#       "flag": "Organ Donor: YES",
#       "flag_attributes": {
#         "organ_donor": "YES"
#       }
#     },
#     {
#       "note": "Temporary address valid until 2025-01-31.",
#       "note_attributes": {
#         "type": "address_validity"
#       }
#     }
#   ]
# }
#
# Q:
# A:
# INFO:absl:Starting document annotation.
# LangExtract: model=gemini-2.5-flash [00:00]2025-08-17 18:42:34,199 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='STATE OF PACIFICA • DRIVER LICENSE\nDLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18\n')
# 2025-08-17 18:42:34,200 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.5 ms)
# INFO:absl:Processing batch 0 with length 1
# DEBUG:absl:Token util returns string: STATE OF PACIFICA • DRIVER LICENSE
# DLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses
# Name: RIVERA, ALEX J
# Address: 1420 Beacon Ave, Apt 5B, Northport, PC 94021
# DOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18 for tokenized_text: TokenizedText(text='STATE OF PACIFICA • DRIVER LICENSE\nDLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18\n', tokens=[Token(index=0, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=0, end_pos=5), first_token_after_newline=False), Token(index=1, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=6, end_pos=8), first_token_after_newline=False), Token(index=2, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=9, end_pos=17), first_token_after_newline=False), Token(index=3, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=18, end_pos=19), first_token_after_newline=False), Token(index=4, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=20, end_pos=26), first_token_after_newline=False), Token(index=5, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=27, end_pos=34), first_token_after_newline=False), Token(index=6, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=35, end_pos=38), first_token_after_newline=True), Token(index=7, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=38, end_pos=39), first_token_after_newline=False), Token(index=8, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=40, end_pos=41), first_token_after_newline=False), Token(index=9, token_type=<TokenType.NUMBER: 1>, char_interval=CharInterval(start_pos=41, end_pos=44), first_token_after_newline=False), Token(index=10, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=44, end_pos=45), first_token_after_newline=False), Token(index=11, token_type=<TokenType.NUMBER: 1>, char_interval=CharInterval(start_pos=45, end_pos=48), first_token_after_newline=False), Token(index=12, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=48, end_pos=49), first_token_after_newline=False), Token(index=13, token_type=<TokenType.NUMBER: 1>, char_interval=CharInterval(start_pos=49, end_pos=52), first_token_after_newline=False), Token(index=14, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=55, end_pos=60), first_token_after_newline=False), Token(index=15, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=60, end_pos=61), first_token_after_newline=False), Token(index=16, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=62, end_pos=63), first_token_after_newline=False), Token(index=17, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=66, end_pos=78), first_token_after_newline=False), Token(index=18, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=78, end_pos=79), first_token_after_newline=False), Token(index=19, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=80, end_pos=84), first_token_after_newline=False), Token(index=20, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=87, end_pos=92), first_token_after_newline=False), Token(index=21, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=92, end_pos=93), first_token_after_newline=False), Token(index=22, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=94, end_pos=104), first_token_after_newline=False), Token(index=23, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=105, end_pos=111), first_token_after_newline=False), Token(index=24, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=112, end_pos=116), first_token_after_newline=True), Token(index=25, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=116, end_pos=117), first_token_after_newline=False), Token(index=26, token_type=<TokenType.WORD: 0>, char_interval ...
# LangExtract: model=gemini-2.5-flash, current=240 chars, processed=240 chars:  [00:00]DEBUG:absl:Processing chunk: TextChunk(
#   interval=[start_index: 0, end_index: 65],
#   Document ID: doc_a18c6cb2,
#   Chunk Text: 'STATE OF PACIFICA • DRIVER LICENSE
# DLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses
# Name: RIVERA, ALEX J
# Address: 1420 Beacon Ave, Apt 5B, Northport, PC 94021
# DOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18'
# )
# DEBUG:absl:Top inference result: {
#   "extractions": [
#     {
#       "document": "DRIVER LICENSE",
#       "document_attributes": {
#         "jurisdiction": "STATE OF PACIFICA"
#       }
#     },
#     {
#       "id_number": "P123-456-789",
#       "id_number_attributes": {
#         "label": "DLN"
#       }
#     },
#     {
#       "person": "RIVERA, ALEX J",
#       "person_attributes": {
#         "given_name": "ALEX",
#         "family_name": "RIVERA",
#         "middle_initial": "J"
#       }
#     },
#     {
#       "address": "1420 Beacon Ave, Apt 5B, Northport, PC 94021",
#       "address_attributes": {
#         "city": "Northport",
#         "postal_code": "94021",
#         "region": "PC"
#       }
#     },
#     {
#       "date": "1991-07-18",
#       "date_attributes": {
#         "type": "DOB"
#       }
#     },
#     {
#       "date": "2024-06-15",
#       "date_attributes": {
#         "type": "Issue"
#       }
#     },
#     {
#       "date": "2032-07-18",
#       "date_attributes": {
#         "type": "Exp"
#       }
#     },
#     {
#       "classification": "Class: C",
#       "classification_attributes": {
#         "class": "C"
#       }
#     },
#     {
#       "endorsement": "Endorsements: None",
#       "endorsement_attributes": {
#         "endorsements": "None"
#       }
#     },
#     {
#       "restriction": "Restr: Corrective Lenses",
#       "restriction_attributes": {
#         "restriction": "Corrective Lenses"
#       }
#     }
#   ]
# }
# INFO:absl:Starting resolver process for input text.
# DEBUG:absl:Input Text: {
#   "extractions": [
#     {
#       "document": "DRIVER LICENSE",
#       "document_attributes": {
#         "jurisdiction": "STATE OF PACIFICA"
#       }
#     },
#     {
#       "id_number": "P123-456-789",
#       "id_number_attributes": {
#         "label": "DLN"
#       }
#     },
#     {
#       "person": "RIVERA, ALEX J",
#       "person_attributes": {
#         "given_name": "ALEX",
#         "family_name": "RIVERA",
#         "middle_initial": "J"
#       }
#     },
#     {
#       "address": "1420 Beacon Ave, Apt 5B, Northport, PC 94021",
#       "address_attributes": {
#         "city": "Northport",
#         "postal_code": "94021",
#         "region": "PC"
#       }
#     },
#     {
#       "date": "1991-07-18",
#       "date_attributes": {
#         "type": "DOB"
#       }
#     },
#     {
#       "date": "2024-06-15",
#       "date_attributes": {
#         "type": "Issue"
#       }
#     },
#     {
#       "date": "2032-07-18",
#       "date_attributes": {
#         "type": "Exp"
#       }
#     },
#     {
#       "classification": "Class: C",
#       "classification_attributes": {
#         "class": "C"
#       }
#     },
#     {
#       "endorsement": "Endorsements: None",
#       "endorsement_attributes": {
#         "endorsements": "None"
#       }
#     },
#     {
#       "restriction": "Restr: Corrective Lenses",
#       "restriction_attributes": {
#         "restriction": "Corrective Lenses"
#       }
#     }
#   ]
# }
# INFO:absl:Starting string parsing.
# DEBUG:absl:input_string: {
#   "extractions": [
#     {
#       "document": "DRIVER LICENSE",
#       "document_attributes": {
#         "jurisdiction": "STATE OF PACIFICA"
#       }
#     },
#     {
#       "id_number": "P123-456-789",
#       "id_number_attributes": {
#         "label": "DLN"
#       }
#     },
#     {
#       "person": "RIVERA, ALEX J",
#       "person_attributes": {
#         "given_name": "ALEX",
#         "family_name": "RIVERA",
#         "middle_initial": "J"
#       }
#     },
#     {
#       "address": "1420 Beacon Ave, Apt 5B, Northport, PC 94021",
#       "address_attributes": {
#         "city": "Northport",
#         "postal_code": "94021",
#         "region": "PC"
#       }
#     },
#     {
#       "date": "1991-07-18",
#       "date_attributes": {
#         "type": "DOB"
#       }
#     },
#     {
#       "date": "2024-06-15",
#       "date_attributes": {
#         "type": "Issue"
#       }
#     },
#     {
#       "date": "2032-07-18",
#       "date_attributes": {
#         "type": "Exp"
#       }
#     },
#     {
#       "classification": "Class: C",
#       "classification_attributes": {
#         "class": "C"
#       }
#     },
#     {
#       "endorsement": "Endorsements: None",
#       "endorsement_attributes": {
#         "endorsements": "None"
#       }
#     },
#     {
#       "restriction": "Restr: Corrective Lenses",
#       "restriction_attributes": {
#         "restriction": "Corrective Lenses"
#       }
#     }
#   ]
# }
# DEBUG:absl:Successfully parsed content.
# INFO:absl:Completed parsing of string.
# DEBUG:absl:Parsed content: [{'document': 'DRIVER LICENSE', 'document_attributes': {'jurisdiction': 'STATE OF PACIFICA'}}, {'id_number': 'P123-456-789', 'id_number_attributes': {'label': 'DLN'}}, {'person': 'RIVERA, ALEX J', 'person_attributes': {'given_name': 'ALEX', 'family_name': 'RIVERA', 'middle_initial': 'J'}}, {'address': '1420 Beacon Ave, Apt 5B, Northport, PC 94021', 'address_attributes': {'city': 'Northport', 'postal_code': '94021', 'region': 'PC'}}, {'date': '1991-07-18', 'date_attributes': {'type': 'DOB'}}, {'date': '2024-06-15', 'date_attributes': {'type': 'Issue'}}, {'date': '2032-07-18', 'date_attributes': {'type': 'Exp'}}, {'classification': 'Class: C', 'classification_attributes': {'class': 'C'}}, {'endorsement': 'Endorsements: None', 'endorsement_attributes': {'endorsements': 'None'}}, {'restriction': 'Restr: Corrective Lenses', 'restriction_attributes': {'restriction': 'Corrective Lenses'}}]
# INFO:absl:Starting to extract and order extractions from data.
# INFO:absl:Completed extraction and ordering of extractions.
# DEBUG:absl:Completed the resolver process.
# INFO:absl:Starting alignment process for provided chunk text.
# DEBUG:absl:WordAligner: Starting alignment of extractions with the source text. Extraction groups to align: [[Extraction(extraction_class='document', extraction_text='DRIVER LICENSE', char_interval=None, alignment_status=None, extraction_index=1, group_index=0, description=None, attributes={'jurisdiction': 'STATE OF PACIFICA'}), Extraction(extraction_class='id_number', extraction_text='P123-456-789', char_interval=None, alignment_status=None, extraction_index=2, group_index=1, description=None, attributes={'label': 'DLN'}), Extraction(extraction_class='person', extraction_text='RIVERA, ALEX J', char_interval=None, alignment_status=None, extraction_index=3, group_index=2, description=None, attributes={'given_name': 'ALEX', 'family_name': 'RIVERA', 'middle_initial': 'J'}), Extraction(extraction_class='address', extraction_text='1420 Beacon Ave, Apt 5B, Northport, PC 94021', char_interval=None, alignment_status=None, extraction_index=4, group_index=3, description=None, attributes={'city': 'Northport', 'postal_code': '94021', 'region': 'PC'}), Extraction(extraction_class='date', extraction_text='1991-07-18', char_interval=None, alignment_status=None, extraction_index=5, group_index=4, description=None, attributes={'type': 'DOB'}), Extraction(extraction_class='date', extraction_text='2024-06-15', char_interval=None, alignment_status=None, extraction_index=6, group_index=5, description=None, attributes={'type': 'Issue'}), Extraction(extraction_class='date', extraction_text='2032-07-18', char_interval=None, alignment_status=None, extraction_index=7, group_index=6, description=None, attributes={'type': 'Exp'}), Extraction(extraction_class='classification', extraction_text='Class: C', char_interval=None, alignment_status=None, extraction_index=8, group_index=7, description=None, attributes={'class': 'C'}), Extraction(extraction_class='endorsement', extraction_text='Endorsements: None', char_interval=None, alignment_status=None, extraction_index=9, group_index=8, description=None, attributes={'endorsements': 'None'}), Extraction(extraction_class='restriction', extraction_text='Restr: Corrective Lenses', char_interval=None, alignment_status=None, extraction_index=10, group_index=9, description=None, attributes={'restriction': 'Corrective Lenses'})]]
# 2025-08-17 18:42:40,375 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='STATE OF PACIFICA • DRIVER LICENSE\nDLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18')
# 2025-08-17 18:42:40,376 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.4 ms)
# 2025-08-17 18:42:40,377 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='␟')
# 2025-08-17 18:42:40,378 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Using delimiter '␟' for extraction alignment
# 2025-08-17 18:42:40,380 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='DRIVER LICENSE ␟ P123-456-789 ␟ RIVERA, ALEX J ␟ 1420 Beacon Ave, Apt 5B, Northport, PC 94021 ␟ 1991-07-18 ␟ 2024-06-15 ␟ 2032-07-18 ␟ Class: C ␟ Endorsements: None ␟ Restr: Corrective Lenses')
# 2025-08-17 18:42:40,382 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.4 ms)
# DEBUG:absl:Processing extraction group 0 with 10 extractions.
# 2025-08-17 18:42:40,383 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='DRIVER LICENSE')
# 2025-08-17 18:42:40,384 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,385 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='P123-456-789')
# 2025-08-17 18:42:40,386 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-17 18:42:40,387 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='RIVERA, ALEX J')
# 2025-08-17 18:42:40,388 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-17 18:42:40,388 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='1420 Beacon Ave, Apt 5B, Northport, PC 94021')
# 2025-08-17 18:42:40,389 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-17 18:42:40,390 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='1991-07-18')
# 2025-08-17 18:42:40,391 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,392 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='2024-06-15')
# 2025-08-17 18:42:40,393 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,394 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='2032-07-18')
# 2025-08-17 18:42:40,395 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,396 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Class: C')
# 2025-08-17 18:42:40,397 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,398 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Endorsements: None')
# 2025-08-17 18:42:40,398 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,400 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Restr: Corrective Lenses')
# 2025-08-17 18:42:40,401 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,402 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='STATE OF PACIFICA • DRIVER LICENSE\nDLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032-07-18')
# 2025-08-17 18:42:40,403 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.4 ms)
# 2025-08-17 18:42:40,404 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='DRIVER LICENSE')
# 2025-08-17 18:42:40,405 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,417 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='P123-456-789')
# 2025-08-17 18:42:40,418 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-17 18:42:40,419 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='RIVERA, ALEX J')
# 2025-08-17 18:42:40,420 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,421 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='1420 Beacon Ave, Apt 5B, Northport, PC 94021')
# 2025-08-17 18:42:40,422 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-17 18:42:40,423 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='1991-07-18')
# 2025-08-17 18:42:40,423 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,424 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='2024-06-15')
# 2025-08-17 18:42:40,425 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-17 18:42:40,426 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='2032-07-18')
# 2025-08-17 18:42:40,427 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Starting fuzzy alignment for 3 unaligned extractions
# 2025-08-17 18:42:40,428 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Class: C')
# 2025-08-17 18:42:40,430 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Fuzzy aligning 'Class: C' (3 tokens)
# DEBUG:absl:Fuzzy alignment successful for extraction: Class: C
# 2025-08-17 18:42:40,476 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Endorsements: None')
# 2025-08-17 18:42:40,478 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# DEBUG:absl:Fuzzy aligning 'Endorsements: None' (3 tokens)
# DEBUG:absl:Fuzzy alignment successful for extraction: Endorsements: None
# 2025-08-17 18:42:40,510 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Restr: Corrective Lenses')
# 2025-08-17 18:42:40,510 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# DEBUG:absl:Fuzzy aligning 'Restr: Corrective Lenses' (4 tokens)
# DEBUG:absl:Fuzzy alignment successful for extraction: Restr: Corrective Lenses
# DEBUG:absl:Final aligned extraction groups: [[Extraction(extraction_class='document', extraction_text='DRIVER LICENSE', char_interval=CharInterval(start_pos=20, end_pos=34), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'jurisdiction': 'STATE OF PACIFICA'}), Extraction(extraction_class='id_number', extraction_text='P123-456-789', char_interval=CharInterval(start_pos=40, end_pos=52), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'label': 'DLN'}), Extraction(extraction_class='person', extraction_text='RIVERA, ALEX J', char_interval=CharInterval(start_pos=118, end_pos=132), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'given_name': 'ALEX', 'family_name': 'RIVERA', 'middle_initial': 'J'}), Extraction(extraction_class='address', extraction_text='1420 Beacon Ave, Apt 5B, Northport, PC 94021', char_interval=CharInterval(start_pos=142, end_pos=186), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'city': 'Northport', 'postal_code': '94021', 'region': 'PC'}), Extraction(extraction_class='date', extraction_text='1991-07-18', char_interval=CharInterval(start_pos=192, end_pos=202), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=5, group_index=4, description=None, attributes={'type': 'DOB'}), Extraction(extraction_class='date', extraction_text='2024-06-15', char_interval=CharInterval(start_pos=212, end_pos=222), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=6, group_index=5, description=None, attributes={'type': 'Issue'}), Extraction(extraction_class='date', extraction_text='2032-07-18', char_interval=CharInterval(start_pos=230, end_pos=240), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=7, group_index=6, description=None, attributes={'type': 'Exp'}), Extraction(extraction_class='classification', extraction_text='Class: C', char_interval=CharInterval(start_pos=55, end_pos=63), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=8, group_index=7, description=None, attributes={'class': 'C'}), Extraction(extraction_class='endorsement', extraction_text='Endorsements: None', char_interval=CharInterval(start_pos=66, end_pos=84), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=9, group_index=8, description=None, attributes={'endorsements': 'None'}), Extraction(extraction_class='restriction', extraction_text='Restr: Corrective Lenses', char_interval=CharInterval(start_pos=87, end_pos=111), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=10, group_index=9, description=None, attributes={'restriction': 'Corrective Lenses'})]]
# DEBUG:absl:Aligned extractions count: 10
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='document', extraction_text='DRIVER LICENSE', char_interval=CharInterval(start_pos=20, end_pos=34), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'jurisdiction': 'STATE OF PACIFICA'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='id_number', extraction_text='P123-456-789', char_interval=CharInterval(start_pos=40, end_pos=52), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'label': 'DLN'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='person', extraction_text='RIVERA, ALEX J', char_interval=CharInterval(start_pos=118, end_pos=132), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'given_name': 'ALEX', 'family_name': 'RIVERA', 'middle_initial': 'J'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='address', extraction_text='1420 Beacon Ave, Apt 5B, Northport, PC 94021', char_interval=CharInterval(start_pos=142, end_pos=186), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'city': 'Northport', 'postal_code': '94021', 'region': 'PC'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='date', extraction_text='1991-07-18', char_interval=CharInterval(start_pos=192, end_pos=202), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=5, group_index=4, description=None, attributes={'type': 'DOB'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='date', extraction_text='2024-06-15', char_interval=CharInterval(start_pos=212, end_pos=222), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=6, group_index=5, description=None, attributes={'type': 'Issue'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='date', extraction_text='2032-07-18', char_interval=CharInterval(start_pos=230, end_pos=240), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=7, group_index=6, description=None, attributes={'type': 'Exp'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='classification', extraction_text='Class: C', char_interval=CharInterval(start_pos=55, end_pos=63), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=8, group_index=7, description=None, attributes={'class': 'C'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='endorsement', extraction_text='Endorsements: None', char_interval=CharInterval(start_pos=66, end_pos=84), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=9, group_index=8, description=None, attributes={'endorsements': 'None'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='restriction', extraction_text='Restr: Corrective Lenses', char_interval=CharInterval(start_pos=87, end_pos=111), alignment_status=<AlignmentStatus.MATCH_FUZZY: 'match_fuzzy'>, extraction_index=10, group_index=9, description=None, attributes={'restriction': 'Corrective Lenses'})
# INFO:absl:Completed alignment process for the provided source_text.
# LangExtract: model=gemini-2.5-flash, current=240 chars, processed=240 chars:  [00:06]
# ✓ Extraction processing complete
# INFO:absl:Finalizing annotation for document ID doc_a18c6cb2.
# INFO:absl:Document annotation completed.
# ✓ Extracted 10 entities (8 unique types)
#   • Time: 6.36s
#   • Speed: 38 chars/sec
#   • Chunks: 1
# Extracted 10 entities:
#
# • document: 'DRIVER LICENSE'
#   - jurisdiction: STATE OF PACIFICA
# • id_number: 'P123-456-789'
#   - label: DLN
# • person: 'RIVERA, ALEX J'
#   - given_name: ALEX
#   - family_name: RIVERA
#   - middle_initial: J
# • address: '1420 Beacon Ave, Apt 5B, Northport, PC 94021'
#   - city: Northport
#   - postal_code: 94021
#   - region: PC
# • date: '1991-07-18'
#   - type: DOB
# • date: '2024-06-15'
#   - type: Issue
# • date: '2032-07-18'
#   - type: Exp
# • classification: 'Class: C'
#   - class: C
# • endorsement: 'Endorsements: None'
#   - endorsements: None
# • restriction: 'Restr: Corrective Lenses'
#   - restriction: Corrective Lenses

# %% [markdown]
# ## Interactive Visualization

# %%
# Save results to JSONL
lx.io.save_annotated_documents([result], output_name="fake_license.jsonl", output_dir=".")

# Generate interactive visualization
html_content = lx.visualize("fake_license.jsonl")

# Display in notebook
print("Interactive visualization (hover over highlights to see attributes):")
html_content
# Out:
# LangExtract: Saving to fake_license.jsonl: 1 docs [00:00, 492.17 docs/s]
# ✓ Saved 1 documents to fake_license.jsonl
# LangExtract: Loading fake_license.jsonl: 100%|██████████| 3.00k/3.00k [00:00<00:00, 7.82MB/s]
# ✓ Loaded 1 documents from fake_license.jsonl
# Interactive visualization (hover over highlights to see attributes):
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">address</span> <span class="lx-label" style="background-color:#C8E6C9;">classification</span> <span class="lx-label" style="background-color:#FEF0C3;">date</span> <span class="lx-label" style="background-color:#F9DEDC;">document</span> <span class="lx-label" style="background-color:#FFDDBE;">endorsement</span> <span class="lx-label" style="background-color:#EADDFF;">id_number</span> <span class="lx-label" style="background-color:#C4E9E4;">person</span> <span class="lx-label" style="background-color:#FCE4EC;">restriction</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         STATE OF PACIFICA • <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#F9DEDC;">DRIVER LICENSE</span>
# DLN: <span class="lx-highlight" data-idx="1" style="background-color:#EADDFF;">P123-456-789</span>   <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">Class: C</span>   <span class="lx-highlight" data-idx="3" style="background-color:#FFDDBE;">Endorsements: None</span>   <span class="lx-highlight" data-idx="4" style="background-color:#FCE4EC;">Restr: Corrective Lenses</span>
# Name: <span class="lx-highlight" data-idx="5" style="background-color:#C4E9E4;">RIVERA, ALEX J</span>
# Address: <span class="lx-highlight" data-idx="6" style="background-color:#D2E3FC;">1420 Beacon Ave, Apt 5B, Northport, PC 94021</span>
# DOB: <span class="lx-highlight" data-idx="7" style="background-color:#FEF0C3;">1991-07-18</span>   Issue: <span class="lx-highlight" data-idx="8" style="background-color:#FEF0C3;">2024-06-15</span>   Exp: <span class="lx-highlight" data-idx="9" style="background-color:#FEF0C3;">2032-07-18</span>
#
#       </div>
#       <div class="lx-controls">
#         <div class="lx-button-row">
#           <button class="lx-control-btn" onclick="playPause()">▶️ Play</button>
#           <button class="lx-control-btn" onclick="prevExtraction()">⏮ Previous</button>
#           <button class="lx-control-btn" onclick="nextExtraction()">⏭ Next</button>
#         </div>
#         <div class="lx-progress-container">
#           <input type="range" id="progressSlider" class="lx-progress-slider"
#                  min="0" max="9" value="0"
#                  onchange="jumpToExtraction(this.value)">
#         </div>
#         <div class="lx-status-text">
#           Entity <span id="entityInfo">1/10</span> |
#           Pos <span id="posInfo">[20-34]</span>
#         </div>
#       </div>
#     </div>
#
#     <script>
#       (function() {
#         const extractions = [{"index": 0, "class": "document", "text": "DRIVER LICENSE", "color": "#F9DEDC", "startPos": 20, "endPos": 34, "beforeText": "STATE OF PACIFICA \u2022 ", "extractionText": "DRIVER LICENSE", "afterText": "\nDLN: P123-456-789   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 940", "attributesHtml": "<div><strong>class:</strong> document</div><div><strong>attributes:</strong> {<span class=\"lx-attr-key\">jurisdiction</span>: <span class=\"lx-attr-value\">STATE OF PACIFICA</span>}</div>"}, {"index": 1, "class": "id_number", "text": "P123-456-789", "color": "#EADDFF", "startPos": 40, "endPos": 52, "beforeText": "STATE OF PACIFICA \u2022 DRIVER LICENSE\nDLN: ", "extractionText": "P123-456-789", "afterText": "   Class: C   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18", "attributesHtml": "<div><strong>class:</strong> id_number</div><div><strong>attributes:</strong> {<span class=\"lx-attr-key\">label</span>: <span class=\"lx-attr-value\">DLN</span>}</div>"}, {"index": 2, "class": "classification", "text": "Class: C", "color": "#C8E6C9", "startPos": 55, "endPos": 63, "beforeText": "STATE OF PACIFICA \u2022 DRIVER LICENSE\nDLN: P123-456-789   ", "extractionText": "Class: C", "afterText": "   Endorsements: None   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2", "attributesHtml": "<div><strong>class:</strong> classification</div><div><strong>attributes:</strong> {<span class=\"lx-attr-key\">class</span>: <span class=\"lx-attr-value\">C</span>}</div>"}, {"index": 3, "class": "endorsement", "text": "Endorsements: None", "color": "#FFDDBE", "startPos": 66, "endPos": 84, "beforeText": "STATE OF PACIFICA \u2022 DRIVER LICENSE\nDLN: P123-456-789   Class: C   ", "extractionText": "Endorsements: None", "afterText": "   Restr: Corrective Lenses\nName: RIVERA, ALEX J\nAddress: 1420 Beacon Ave, Apt 5B, Northport, PC 94021\nDOB: 1991-07-18   Issue: 2024-06-15   Exp: 2032", "attributesHtml": "<div><strong>class:</strong> endorsement</div><div><strong>attributes:</strong> {<span class=\"lx-attr-key\">endorsements</span>

# %%
# Save visualization to file (for downloading)
with open("fake_license.html", "w") as f:
    # Handle both Jupyter (HTML object) and non-Jupyter (string) environments
    if hasattr(html_content, 'data'):
        f.write(html_content.data)
    else:
        f.write(html_content)

print("✓ Visualization saved to fake_license.html")
print("You can download this file from the Files panel on the left.")
# Out:
# ✓ Visualization saved to fake_license.html
# You can download this file from the Files panel on the left.

# %% [markdown]
# ## Try Your Own Text
#
# Experiment with your own Shakespeare quotes or any literary text!

# %%
# Try your own text
your_text = """
JULIET: O Romeo, Romeo! wherefore art thou Romeo?
Deny thy father and refuse thy name;
Or, if thou wilt not, be but sworn my love,
And I'll no longer be a Capulet.
"""

custom_result = lx.extract(
    text_or_documents=your_text,
    prompt_description=prompt,
    examples=examples,
    model_id="gemini-2.5-flash",
)

print("Extractions from your text:\n")
for e in custom_result.extractions:
    print(f"• {e.extraction_class}: '{e.extraction_text}'")
    if e.attributes:
        for key, value in e.attributes.items():
            print(f"  - {key}: {value}")
# Out:
# LangExtract: model=gemini-2.5-flash, current=163 chars, processed=163 chars:  [00:05]
# ✓ Extraction processing complete
# ✓ Extracted 6 entities (3 unique types)
#   • Time: 5.84s
#   • Speed: 28 chars/sec
#   • Chunks: 1
# Extractions from your text:
#
# • character: 'JULIET'
#   - emotional_state: longing
# • emotion: 'O Romeo, Romeo! wherefore art thou Romeo?'
#   - feeling: desperate questioning
# • relationship: 'thy father'
#   - type: familial
# • relationship: 'thy name'
#   - type: lineage
# • relationship: 'my love'
#   - type: romantic bond
# • relationship: 'Capulet'
#   - type: family affiliation
